# %% [markdown]
# <img src="https://static.wincacademy.nl/logos/main-logo.png" height=200px style="height: 200px"/>

# %%
# !pip install matplotlib --user > /dev/null 2>&1
# !pip install numpy --user > /dev/null 2>&1
# !pip install pandas --user > /dev/null 2>&1

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import csv

# %% [markdown]
# # Data Preparation
#
# ## CSV
#
# Let's talk about the messy part of data analytics: preparing data. Before doing the interesting work of data analytics, we need to:
#
# 1. Gather the data.
# 2. Structure the data in such a way that we can work with it in our programs.
# 3. Clean the data, which may include dealing with missing or unreasonable values.
#
# Here we'll assume gathering the data has been done for us. We'll use a dataset provided by the Dutch *Rijksinstituut voor Volksgezondheid en Milieu* (RIVM, translation: National Institute for Health and Environment). It contains COVID-19 numbers per municipality per day. You should place a copy of the data in a file called `covid-data.csv` located in the same folder as this notebook (be it in Google Colab or locally). You can use the URL below to retrieve it.
#
# - Source: Rijksinstituut voor Volksgezondheid en Milieu
# - Data URL: https://data.rivm.nl/covid-19/COVID-19_aantallen_gemeente_per_dag.csv

# %%
data_loc = 'covid-data.csv'
covid_data = open(data_loc).read()

# %% [markdown]
# Let's take a look at what it looks like by printing the first 1000 characters.

# %%
print(covid_data[:1000])
# Out:
# Date_of_report;Date_of_publication;Municipality_code;Municipality_name;Province;Security_region_code;Security_region_name;Municipal_health_service;ROAZ_region;Total_reported;Hospital_admission;Deceased,
# 2021-03-24 10:00:00;2020-02-27;GM0014;Groningen;Groningen;VR01;Groningen;GGD Groningen;Acute Zorgnetwerk Noord Nederland;0;0;0,
# 2021-03-24 10:00:00;2020-02-27;GM0034;Almere;Flevoland;VR25;Flevoland;GGD Flevoland;SpoedZorgNet;0;0;0,
# 2021-03-24 10:00:00;2020-02-27;GM0037;Stadskanaal;Groningen;VR01;Groningen;GGD Groningen;Acute Zorgnetwerk Noord Nederland;0;0;0,
# 2021-03-24 10:00:00;2020-02-27;GM0047;Veendam;Groningen;VR01;Groningen;GGD Groningen;Acute Zorgnetwerk Noord Nederland;0;0;0,
# 2021-03-24 10:00:00;2020-02-27;GM0050;Zeewolde;Flevoland;VR25;Flevoland;GGD Flevoland;SpoedZorgNet;0;0;0,
# 2021-03-24 10:00:00;2020-02-27;GM0059;Achtkarspelen;Fryslân;VR02;Fryslân;GGD Fryslân;Acute Zorgnetwerk Noord Nederland;0;0;0,
# 2021-03-24 10:00:00;2020-02-27;GM0060;Ameland;Fryslân;VR02;Fryslân;GGD Fryslâ

# %% [markdown]
# That looks pretty chaotic. The data is in a format called `csv`, which is a commonly used format to store and share data.
#
# 1. A `csv` file contains only text.
# 2. The first line a `csv` file lists column names.
# 3. Each line after that is a datapoint with values for those columns in the same order.
#
# Let's look at the first 3 lines instead of the first 1000 characters.

# %%
for line in covid_data.split('\n')[:3]:
    print(line)
# Out:
# Date_of_report;Date_of_publication;Municipality_code;Municipality_name;Province;Security_region_code;Security_region_name;Municipal_health_service;ROAZ_region;Total_reported;Hospital_admission;Deceased,
# 2021-03-24 10:00:00;2020-02-27;GM0014;Groningen;Groningen;VR01;Groningen;GGD Groningen;Acute Zorgnetwerk Noord Nederland;0;0;0,
# 2021-03-24 10:00:00;2020-02-27;GM0034;Almere;Flevoland;VR25;Flevoland;GGD Flevoland;SpoedZorgNet;0;0;0,

# %% [markdown]
# **1. What are the column names for this dataset? List them here.**
#
# Date_of_report
# Date_of_publication
# Municipality_code
# Municipality_name
# Province
# Security_region_code
# Security_region_name
# Municipal_health_service
# ROAZ_region
# Total_reported
# Hospital_admission
# Deceased
#
# **2. Which character separates the datapoints from each other? Put an `x` in the right box.**
#
# - [x] A linebreak
# - [ ] A tab
# - [ ] A comma
#
# **3. Which character separates the columns within a datapoint from each other?**
#
# ;
#
#
# ### Parsing
#
# Let's use this information to read the data into our program in a better way. This is known as [*parsing*](https://en.wikipedia.org/wiki/Parsing). Our goal is to structure the data in such a way that we'll be able to write code like this to make it easier to work with the data:
#
# ```python
# # For some datapoint, show me the municipality that it concerns.
# some_datapoint['Municipality_name']
# ```
#
# By answering the questions above we have all the information we need to organize the internal *data structure* in this way.
#
# - We know what separates datapoints from each other.
# - We know how columns are separated within datapoints.
# - We have the column names for each datapoint.
#
# We can use this information to instruct Python -- the programming language we're using here -- to create a *data structure* that we can use like in the example above. Once completed, we'll have *parsed* the CSV file.
#
# **4. What is parsing in your own words?**
#
# Applying the correct rules/language to understand the provided string of text
#
# **5. Fill in the right column delimiter in the code cell below to complete the code.**

# %%
# TODO: Change PLACEHOLDER to the actual delimiter.
delimiter = ';'
# Make sure the delimiter is surrounded by quotes, for example: delimiter = '<' if the delimiter is <

with open(data_loc) as f:
    csv_reader = csv.DictReader(f, delimiter=delimiter)
    print('Municipality name\tTotal cases reported')
    print('{:=>45}'.format(''))
    data_dicts = list(csv_reader)

for row in data_dicts[:15]:
    print('{:<23} {:<5}'.format(row['Municipality_name'], row['Total_reported']))
# Out:
# Municipality name	Total cases reported
# =============================================
# Groningen               0
# Almere                  0
# Stadskanaal             0
# Veendam                 0
# Zeewolde                0
# Achtkarspelen           0
# Ameland                 0
# Harlingen               0
# Heerenveen              0
# Leeuwarden              0
# Ooststellingwerf        0
# Opsterland              0
# Schiermonnikoog         0
# Smallingerland          0
# Terschelling            0

# %% [markdown]
# Note: Your delimiter was not filled in (correctly) if you got one of these errors:
#
# ```python
# TypeError: "delimiter" must be a 1-character string
# KeyError: 'Municipality_name'
# ```
#
# ## Metadata
#
# Alright, this is much better that looking at raw text, like we did before parsing. We'll get to even better views of the data later. First, let's take a look at some *metadata* -- data about data.
# - The number of datapoints
# - The number of columns
# - The names of the columns (again)
# - The number of missing or empty values
# - The number of unique values in each column

# %%
from collections import defaultdict

print(f'Number of datapoints: {len(data_dicts)}')
print(f'Number of columns: {len(data_dicts[0])}')
print('Column names:')
for k in data_dicts[0].keys():
    print(f'- {k}')
    
unique_vals = [set() for _ in data_dicts[0].keys()]
missing = 0
for datapoint in data_dicts:
    for i, val in enumerate(datapoint.values()):
        unique_vals[i].add(val)
        if val is None or val == '':
            missing += 1
print(f'Missing/empty values: {missing}')

print('Number of unique values:')
for i, k in enumerate(data_dicts[0].keys()):
    print('- {:<25}{:5}'.format(k, len(unique_vals[i])))
# Out:
# Number of datapoints: 148176
# Number of columns: 12
# Column names:
# - Date_of_report
# - Date_of_publication
# - Municipality_code
# - Municipality_name
# - Province
# - Security_region_code
# - Security_region_name
# - Municipal_health_service
# - ROAZ_region
# - Total_reported
# - Hospital_admission
# - Deceased,
# Missing/empty values: 22736
# Number of unique values:
# - Date_of_report               1
# - Date_of_publication        392
# - Municipality_code          353
# - Municipality_name          353
# - Province                    12
# - Security_region_code        26
# - Security_region_name        26
# - Municipal_health_service    25
# - ROAZ_region                 12
# - Total_reported             366
# - Hospital_admission          30
# - Deceased,                   23

# %% [markdown]
# **6. Note three questions that you have about the data based on this metadata. It might be something like:**
#
# > **"What is the first and last *date of publication* in the dataset?"**
#
# For which columns we have the most empty values?
# Which city is mentioned most often?
# For which city(ies) do we have the biggest deviation between date of report and date of publication?
#
# **7. Note another metadata property that you would like to know about that's not listed here.**
#
# The number of double values per column
#
# ## Working with dates
#
# Looking at the metadata is a good way to get a feel for what a dataset looks like, and what type of questions you can answer with it. Let's use our example question to proceed with data preparation:
#
# > What is the first and last *date of publication* in the dataset?
#
# To answer this question, we can't just assume the first date is at the top and the last date is at the bottom, or vice versa. We need some way to do compare the dates and find out which one is the first and which one is the last. Let's first inspect a few entries in the `Date_of_publication` column to see what they look like.

# %%
print('The current datatype for the Date_of_publication column is:', type(data_dicts[0]['Date_of_publication']))
for row in data_dicts[::int(len(data_dicts) / 20)]:
    print(row['Date_of_publication'])
# Out:
# The current datatype for the Date_of_publication column is: <class 'str'>
# 2020-02-27
# 2020-03-17
# 2020-04-06
# 2020-04-25
# 2020-05-15
# 2020-06-03
# 2020-06-23
# 2020-07-13
# 2020-08-01
# 2020-08-21
# 2020-09-09
# 2020-09-29
# 2020-10-19
# 2020-11-07
# 2020-11-27
# 2020-12-16
# 2021-01-05
# 2021-01-25
# 2021-02-13
# 2021-03-05
# 2021-03-24

# %% [markdown]
# We see that the data type is `str`, which is short for *string*, the programming term for *text*. We can't do any clever comparing with just text. We need to *parse* these dates to be able to make comparisons between them.
#
# Fortunately, the dates are then specified in a certain *date format*. For example, in the Netherlands people often write '24/12/1980' for the 24th day of December in the year 1980. We could specify that format as `DD/MM/YYYY`.
#
# - `DD` stands for 'Two numbers that represent the day'.
# - `MM` stands for 'Two numbers that represent the month'.
# - `YYYY` stands for 'Four numbers that represent the year'.
#
# If they wrote `-` instead of `/`, like so: '24-12-1980', the format would be `DD-MM-YYYY`.
#
# **8. What is the *date format* in the `Date_of_publication` column in our dataset?**
#
# YYYY-MM-DD
#
# **9. Fill in this format in the placeholder in the code block below.**
#
# - **Use `%Y` for `YYYY`.**
# - **Use `%m` for `MM`.**
# - **Use `%d` for `DD`.**
#
# **For example, the Dutch date format ('DD/MM/YYYY' would be `'%d/%m/%Y'`)**

# %%
from datetime import datetime

# TODO: Fill in date format for PLACEHOLDER in the next line.
date_format = '%Y-%m-%d'
# Don't modify anything below this line.

for row in data_dicts:
    formatted_date = datetime.strptime(row['Date_of_publication'], date_format).date()
    row['Date_of_publication'] = formatted_date
    
print('The new datatype for the Date_of_publication column is:', type(data_dicts[0]['Date_of_publication']))
# Out:
# The new datatype for the Date_of_publication column is: <class 'datetime.date'>

# %% [markdown]
# If you get an error like the following, your `date_format` is not correct yet.
#
# ```python
# ValueError: time data '2020-02-27' does not match format 'PLACEHOLDER'
# ```
#
# After filling in `date_format` correctly, you should see a line that confirms that the new datatype for this column is `datetime.date`. Great! Now we can compare the dates in the column and answer our original question:
#
# > What is the first and last *date of publication* in the dataset?
#
# We can now compare the dates with:
#
# - `a > b`: this checks if `a` is *later* than `b`.
# - `a < b`: this checks if `a` is *earlier* than `b`.

# %%
# We make the assumption that the date of publication of the first datapoint is the only date. 
first_date_of_publication = data_dicts[0]['Date_of_publication']
last_date_of_publication = data_dicts[0]['Date_of_publication']
# Then we see if we can find any earlier ones, or later ones.
for row in data_dicts:
    # Check if this date is earlier than the currently known first date of publication
    if row['Date_of_publication'] < first_date_of_publication:
        # If so, this is now the new earliest date.
        first_date_of_publication = row['Date_of_publication']
    # Check if this date is later than the currently known last date of publication
    elif row['Date_of_publication'] > last_date_of_publication:
        # If so, this is now the new latest date.
        last_date_of_publication = row['Date_of_publication']

print(f'The first date of publication is {first_date_of_publication}')
print(f'The last date of publication is {last_date_of_publication}')
print(f'The dataset spans {(last_date_of_publication - first_date_of_publication).days} days')

# %% [markdown]
# Cool! We now have a better understanding of what the `Date_of_publication` column looks like.
#
# **10. Explain, in your own words, what a string is.**
#
# A line of text used in programming language
#
# **11. Explain, in your own words, what a date string is.**
#
# a line of text describing a date
#
# **12. Explain, in your own words, why we converted date strings to a `datetime.date` type.**
#
# To enable comparison of the dates; we can't compare strings with eachother, so we have to convert it into something we can compare
#
#
# ## Working with numbers
#
# We'd like to wrap up this lesson with a nice visualization of how many COVID cases were reported over time in a certain municipality. For that we not only have to work with strings and dates, but also with *numbers*. We can find the right number in the `Total_reported` column, but again, it's not yet in the right format. It's a string, while it needs to be a number.
#
# Let's apply the same strategy that we used with dates before. Note that if you run the cell below multiple times, it will no longer show that the column values used to be a strings -- they were converted the first time.

# %%
print('The current datatype for the Total_reported column is:', type(data_dicts[0]['Total_reported']))
for row in data_dicts:
    row['Total_reported'] = int(row['Total_reported'])
print('The new datatype for the Total_reported column is:', type(data_dicts[0]['Total_reported']))
# Out:
# The current datatype for the Total_reported column is: <class 'str'>
# The new datatype for the Total_reported column is: <class 'int'>

# %% [markdown]
# The new datatype for the `Total_reported` column is `int`, which stands for *integer*. This is the programming term for *whole number*. Bonus: the term for a decimal number is *float*.
#
# **13. Which variable in the code snippet below is an integer? (write an `x` in the right box)**
#
# ```python
# a = 'Hello, world!'
# b = 42
# ```
#
# - [ ] `a`
# - [x] `b`
#
# **14. Which variable in the code snippet below is an integer? (write an `x` in the right box)**
#
# ```python
# a = '42'
# b = 42
# ```
#
# - [ ] `a`
# - [x] `b`
#
# Now that the `Total_reported` column has the correct datatype, let's write a script that tells us the reported number per municipality. For convenience, we first print a list of all the municipalities in the dataset.
#
# **15. Choose one of the municipalities printed in the code block below. Then fill it in (exactly as it was displayed) in the next cell and run it to find the total number of reported cases in that municipality.**

# %%
for m in sorted(unique_vals[3]):
    if m != '':
        print('-', m)

# %%
# TODO: FILL IN THE MUNICIPALITY YOU'RE INTERESTED IN HERE
municipality = 'Soest'
# DON'T MODIFY ANYTHING BELOW THIS LINE

reported = 0
for row in data_dicts:
    if row['Municipality_name'] == municipality:
        reported += row['Total_reported']
print(f'The total number of reported cases in {municipality} is {reported}')
# Out:
# The total number of reported cases in Soest is 3081

# %% [markdown]
# Because we have all the data types in order, we can also easily plot the development of new reported cases for that same municipality.

# %%
new_cases_per_day = defaultdict(int)
for row in data_dicts:
        if row['Municipality_name'] == municipality:
            new_cases_per_day[row['Date_of_publication']] += row['Total_reported']
new_cases_per_day = sorted(new_cases_per_day.items(), key=lambda x: x[0])

fig, ax = plt.subplots(figsize=(16,9))
ax.plot([date for date, _ in new_cases_per_day], [cases for _, cases in new_cases_per_day])
ax.set_xlabel('Date')
ax.set_ylabel('Number of new cases');

# %% [markdown]
# ## Missing Data
#
# Finally, a visualization! Let's tackle one final problem: missing data. When we were looking at the metadata, we found that we have $22736$ missing or empty values. Let's print a few datapoints that contain missing values to see what we're dealing with exactly.

# %%
for i, row in enumerate(data_dicts):
    missing_keys = []
    for key, val in row.items():
        if val == '':
            missing_keys.append(key)
    if missing_keys:
        print(f'Row {i} contains empty values for: {missing_keys}')
# Out:
# Streaminguitvoer ingekort tot de laatste 5000 regels.
# Row 72929 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 72930 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 72931 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 72932 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 72933 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 72934 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 72935 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 72936 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 72937 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 72938 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 72939 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 72940 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 72941 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 72942 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 72943 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 72944 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 72945 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 72946 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 72947 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 72948 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 72949 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 72950 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 72951 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 72952 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 72953 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 73307 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73308 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 73309 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73310 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73311 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 73312 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 73313 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73314 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73315 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73316 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 73317 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73318 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 73319 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73320 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73321 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73322 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73323 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73324 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73325 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 73326 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73327 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73328 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73329 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73330 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73331 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 73685 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73686 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 73687 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73688 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73689 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 73690 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 73691 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73692 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73693 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73694 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 73695 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73696 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 73697 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73698 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73699 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73700 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73701 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73702 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73703 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 73704 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73705 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73706 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73707 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73708 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 73709 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 74063 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74064 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 74065 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74066 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74067 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 74068 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 74069 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74070 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74071 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74072 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 74073 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74074 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 74075 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74076 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74077 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74078 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74079 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74080 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74081 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 74082 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74083 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74084 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74085 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74086 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74087 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 74441 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74442 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 74443 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74444 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74445 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 74446 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 74447 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74448 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74449 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74450 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 74451 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74452 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 74453 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74454 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74455 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74456 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74457 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74458 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74459 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 74460 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74461 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74462 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74463 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74464 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74465 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 74819 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74820 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 74821 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74822 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74823 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 74824 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 74825 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74826 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74827 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74828 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 74829 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74830 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 74831 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74832 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74833 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74834 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74835 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74836 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74837 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 74838 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74839 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74840 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74841 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74842 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 74843 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 75197 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75198 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 75199 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75200 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75201 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 75202 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 75203 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75204 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75205 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75206 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 75207 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75208 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 75209 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75210 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75211 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75212 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75213 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75214 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75215 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 75216 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75217 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75218 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75219 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75220 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75221 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 75575 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75576 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 75577 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75578 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75579 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 75580 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 75581 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75582 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75583 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75584 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 75585 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75586 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 75587 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75588 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75589 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75590 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75591 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75592 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75593 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 75594 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75595 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75596 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75597 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75598 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75599 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 75953 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75954 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 75955 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75956 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75957 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 75958 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 75959 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75960 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75961 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75962 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 75963 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75964 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 75965 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75966 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75967 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75968 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75969 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75970 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75971 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 75972 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75973 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75974 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75975 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75976 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 75977 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 76331 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76332 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 76333 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76334 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76335 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 76336 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 76337 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76338 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76339 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76340 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 76341 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76342 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 76343 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76344 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76345 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76346 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76347 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76348 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76349 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 76350 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76351 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76352 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76353 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76354 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76355 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 76709 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76710 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 76711 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76712 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76713 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 76714 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 76715 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76716 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76717 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76718 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 76719 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76720 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 76721 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76722 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76723 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76724 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76725 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76726 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76727 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 76728 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76729 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76730 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76731 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76732 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 76733 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 77087 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77088 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 77089 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77090 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77091 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 77092 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 77093 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77094 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77095 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77096 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 77097 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77098 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 77099 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77100 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77101 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77102 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77103 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77104 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77105 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 77106 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77107 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77108 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77109 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77110 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77111 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 77465 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77466 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 77467 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77468 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77469 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 77470 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 77471 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77472 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77473 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77474 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 77475 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77476 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 77477 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77478 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77479 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77480 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77481 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77482 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77483 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 77484 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77485 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77486 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77487 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77488 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77489 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 77843 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77844 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 77845 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77846 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77847 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 77848 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 77849 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77850 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77851 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77852 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 77853 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77854 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 77855 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77856 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77857 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77858 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77859 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77860 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77861 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 77862 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77863 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77864 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77865 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77866 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 77867 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 78221 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78222 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 78223 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78224 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78225 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 78226 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 78227 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78228 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78229 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78230 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 78231 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78232 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 78233 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78234 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78235 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78236 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78237 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78238 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78239 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 78240 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78241 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78242 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78243 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78244 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78245 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 78599 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78600 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 78601 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78602 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78603 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 78604 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 78605 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78606 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78607 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78608 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 78609 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78610 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 78611 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78612 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78613 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78614 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78615 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78616 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78617 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 78618 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78619 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78620 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78621 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78622 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78623 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 78977 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78978 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 78979 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78980 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78981 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 78982 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 78983 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78984 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78985 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78986 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 78987 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78988 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 78989 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78990 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78991 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78992 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78993 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78994 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78995 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 78996 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78997 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78998 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 78999 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79000 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79001 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 79355 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79356 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 79357 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79358 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79359 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 79360 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 79361 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79362 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79363 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79364 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 79365 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79366 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 79367 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79368 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79369 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79370 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79371 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79372 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79373 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 79374 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79375 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79376 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79377 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79378 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79379 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 79733 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79734 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 79735 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79736 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79737 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 79738 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 79739 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79740 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79741 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79742 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 79743 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79744 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 79745 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79746 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79747 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79748 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79749 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79750 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79751 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 79752 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79753 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79754 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79755 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79756 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 79757 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 80111 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80112 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 80113 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80114 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80115 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 80116 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 80117 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80118 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80119 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80120 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 80121 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80122 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 80123 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80124 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80125 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80126 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80127 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80128 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80129 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 80130 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80131 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80132 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80133 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80134 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80135 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 80489 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80490 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 80491 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80492 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80493 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 80494 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 80495 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80496 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80497 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80498 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 80499 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80500 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 80501 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80502 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80503 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80504 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80505 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80506 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80507 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 80508 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80509 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80510 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80511 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80512 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80513 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 80867 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80868 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 80869 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80870 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80871 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 80872 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 80873 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80874 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80875 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80876 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 80877 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80878 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 80879 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80880 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80881 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80882 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80883 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80884 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80885 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 80886 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80887 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80888 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80889 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80890 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 80891 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 81245 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 81246 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 81247 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 81248 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 81249 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 81250 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 81251 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 81252 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 81253 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 81254 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# ...
# Row 145521 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145522 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145523 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 145524 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145525 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145526 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145527 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145528 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145529 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 145883 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145884 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 145885 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145886 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145887 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 145888 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 145889 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145890 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145891 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145892 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 145893 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145894 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 145895 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145896 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145897 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145898 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145899 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145900 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145901 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 145902 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145903 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145904 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145905 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145906 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145907 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 146261 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146262 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 146263 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146264 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146265 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 146266 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 146267 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146268 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146269 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146270 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 146271 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146272 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 146273 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146274 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146275 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146276 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146277 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146278 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146279 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 146280 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146281 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146282 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146283 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146284 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146285 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 146639 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146640 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 146641 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146642 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146643 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 146644 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 146645 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146646 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146647 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146648 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 146649 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146650 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 146651 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146652 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146653 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146654 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146655 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146656 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146657 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 146658 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146659 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146660 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146661 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146662 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146663 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147017 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147018 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147019 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147020 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147021 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147022 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147023 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147024 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147025 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147026 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147027 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147028 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147029 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147030 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147031 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147032 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147033 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147034 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147035 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 147036 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147037 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147038 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147039 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147040 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147041 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147395 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147396 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147397 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147398 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147399 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147400 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147401 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147402 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147403 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147404 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147405 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147406 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147407 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147408 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147409 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147410 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147411 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147412 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147413 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 147414 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147415 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147416 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147417 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147418 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147419 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147773 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147774 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147775 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147776 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147777 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147778 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147779 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147780 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147781 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147782 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147783 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147784 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147785 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147786 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147787 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147788 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147789 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147790 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147791 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 147792 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147793 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147794 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147795 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147796 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147797 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 148151 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148152 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 148153 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148154 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148155 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 148156 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 148157 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148158 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148159 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148160 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 148161 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148162 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 148163 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148164 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148165 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148166 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148167 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148168 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148169 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 148170 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148171 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148172 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148173 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148174 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148175 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']

# %% [markdown]
# **16. What column(s) is/are missing most often?**
#
# City code and name
#
# Missing data may become a problem if we want to draw comparisons between certain parts of the data. Still, there is no universal and definitive *correct approach* to solving the problem of missing data. In fact, in this case there might actually not be a good way to fill in the missing municipalities here.
#
# For the sake of exercise, we will create a new dataset for your chosen municipality where the `Total_reported` new cases will be replaced with the impossible number `-1` from a number of the dates.
#
# **17. Why is `-1` an impossible number here?**
#
# You can't hand over a negative number of reports, that would mean that the city would receive a report or something, instead of handing it in

# %%
noisy_new_cases_per_day = [(date, cases) if np.random.rand() < 0.8
                           else (date, -1)
                           for date, cases in new_cases_per_day]

fig, ax = plt.subplots(figsize=(16,9))
ax.plot([date for date, _ in new_cases_per_day],
        [cases for _, cases in new_cases_per_day], '.', label='true data')
ax.plot([date for date, _ in noisy_new_cases_per_day],
        [cases for _, cases in noisy_new_cases_per_day],
        label='noisy data')
ax.set_xlabel('Date')
ax.set_ylabel('Number of new cases')
ax.legend();

# %% [markdown]
# This plot is a lot more messy than the clean data plot, in addition to also showing the impossible number `-1`.
#
# **18. What would be a good way to fill in the missing values? You will not need to implement them, so use your imagination.**
#
# Come up with a 'fake' city name and code, and create a separate graph for that 'fake' city.
#
# Here we'll use the mean of the two surrounding dates' values. For example:
#
# 1. `2020-02-03` is missing
# 2. We take the values from the day before, `2020-02-02`, and the day after, `2020-02-04`. If the data from the day before or after is not available, we use the nearest available datapoint instead.
# 3. We add them up
# 4. Divide them by $2$
# 5. We insert the result as the value for `2020-02-03`.
#
# This is a simple way of doing **interpolation** -- estimating missing values within the range of the data we have. This is the opposite of **extrapolation**, where we have estimate values *outside* of the range of the data we have.
#
# Let's see what the implementation and the result look like.

# %%
interpolated_data = []
max_data_index = len(noisy_new_cases_per_day) - 1
for i, (date, x) in enumerate(noisy_new_cases_per_day):
    # If we have an impossible value
    if x == -1:
        delta_left = 1
        # Scan the left side for values that are not -1
        while noisy_new_cases_per_day[i - delta_left][1] == -1:
            delta_left += 1
            # If we're outside of the data we can't do interpolation. It would be extrapolation.
            if i - delta_left < 0:
                continue
    
        # Scan the right side for values that are not -1
        delta_right = 1
        while noisy_new_cases_per_day[i + delta_right][1] == -1:
            delta_right += 1
            # If we're outside of the data we can't do interpolation. It would be extrapolation.
            if i + delta_right > max_data_index:
                continue
        
        # Finally use the mean of two nearest useful values
        interpolated_value = ((noisy_new_cases_per_day[i - delta_left][1]
                               + noisy_new_cases_per_day[i + delta_right][1])
                              / 2)
        interpolated_data.append((date, interpolated_value))
    else:
        interpolated_data.append((date, x))

fig, ax = plt.subplots(figsize=(16,9))
ax.plot([date for date, _ in new_cases_per_day],
        [cases for _, cases in new_cases_per_day], '.', label='true data')
ax.plot([date for date, _ in interpolated_data],
        [cases for _, cases in interpolated_data],
        label='interpolated data')
ax.plot([date for (date, cases) in noisy_new_cases_per_day if cases == -1],
        [cases for _, cases in noisy_new_cases_per_day if cases == -1], '.',
        label='previously missing data')
ax.set_xlabel('Date')
ax.set_ylabel('Number of new cases')
ax.legend();

# %% [markdown]
# **19. Is this a good way to fill in missing values, in your opinion? Explain.**
#
# Yes, you will work with an avarage to clean up the graph. Better than excluding the datapoints from your graph, because the number of missing elements is quite big, and has therefore a big impact on the outcome of the graph
#
# **20. In which cases will this way of filling in missing values work well, and when will it not work well at all? Give an example for both cases.**
#
# It will work fine in this example where the number of sick people will grown 'slowly'.
# The disadvantage is that the missing data will always be plotted within the the boundries of the known data. We will not be able to see any high peeks for example.

# %% [markdown]
# ## Conclusion
#
# Data preparation may not be the most glamorous part of data analytics, but it is quite important. If we do not do it well, every analytics step that comes after will suffer. It is as they say: *garbage in, garbage out*.
#
# It is also good to know that since most data preparation steps are quite general, there are plenty of tools that make doing it a lot easier and faster. All of the above filtering, selecting and interpolating can be done in a few lines of code! But now *you* know how it works under the hood, and why it's so important!
